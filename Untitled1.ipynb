# %% [markdown]
# <a href="https://colab.research.google.com/github/OscarMuchiri/Speed-Convertor/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pycaret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 3.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.6/169.6 kB 6.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.1/486.1 kB 20.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 9.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.8/21.8 MB 66.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.2/302.2 kB 20.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 8.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 82.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 88.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.7/80.7 kB 6.4 MB/s eta 0:00:00
# ...

# %%
from pycaret.datasets import get_data
data=get_data('heart_disease')
# Out:
#    age  sex  chest pain type  resting blood pressure  \
# 0   70    1                4                     130
# 1   67    0                3                     115
# 2   57    1                2                     124
# 3   64    1                4                     128
# 4   74    0                2                     120
#
#    serum cholestoral in mg/dl        fasting blood sugar > 120 mg/dl   \
# 0                               322                                 0
# 1                               564                                 0
# 2                               261                                 0
# 3                               263                                 0
# 4                               269                                 0
#
#    resting electrocardiographic results  maximum heart rate achieved    \
# 0                                     2                            109
# 1                                     2                            160
# ...

# %%
from pycaret.classification import *
s=setup(data,target ='Disease',session_id=123)
# Out:
# <style type="text/css">
# #T_179a8_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_179a8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_179a8_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_179a8_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_179a8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_179a8_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_179a8_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_179a8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_179a8_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_179a8_row1_col1" class="data row1 col1" >Disease</td>
#     </tr>
#     <tr>
#       <th id="T_179a8_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best=compare_models()
# Out:
# <style type="text/css">
# #T_bcf3d th {
#   text-align: left;
# }
# ...

# %%
plot_model(best,plot='confusion_matrix')

# %%
predict_model(best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_9d4fc" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9d4fc_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_9d4fc_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_9d4fc_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_9d4fc_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_9d4fc_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_9d4fc_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_9d4fc_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_9d4fc_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9d4fc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9d4fc_row0_col0" class="data row0 col0" >Ridge Classifier</td>
# ...
